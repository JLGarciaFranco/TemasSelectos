# %% [markdown]
# # Ejercicio 1: Para este ejercicio, crearán un modelo que estima la pérdida económica de un desastre.
#
# 1. Realiza un AED completo (análisis univariado, bivariado y multivariado). Con esta información, elije los predictores adecuados (la variable objetivo es `'economic_loss_usd'`).
#
# > NOTA: Deben elegir los predictores considerando el problema real, la relación estadística entre las variables, y la utilidad y viabilidad del modelo. Deben sustentar porqué han elegido esos predictores en particular.
#
#
# 2. Crea un DataFrame con las variables predictoras elegidas y estandarízalas.
# ¿Cuál es el mejor método de estandarización de datos en este caso?
#
# 3. Crea un DataFrame que contenga la variable objetivo (`'economic_loss_usd'`).
#
# 4. Crea los conjuntos de datos de entrenamiento (80%) y de prueba (20%).
#
# 5. Entrena un modelo de MSV, un modelo de Árboles de desición, y un modelo de RNA. ¿Qué hiperparámetros son los más adecuados?
#
# 6. Obten las predicciones de los modelos.
#
# 7. Realiza la evaluación de los modelos.
#
# ¿Cuál de los dos es mejor haciendo la estimación de los costos?

# %% [markdown]
# # Ejercicio 2: Crearás modelos que clasifiquen especies de pingüinos de acuerdo a sus carácterísticas. Entonces, usando `'penguins.csv'`:
#
# 1. Realiza un AED completo (análisis univariado, bivariado y multivariado). Con esta información, elije los predictores adecuados (la variable objetivo es `'species'`).
#
# 2. Crea un DataFrame con las variables predictoras elegidas y estandarízalas.
# ¿Cuál es el mejor método de estandarización de datos en este caso?
#
# 3. Crea un DataFrame que contenga la variable objetivo (`'species'`).
#
# 4. Crea los conjuntos de datos de entrenamiento (80%) y de prueba (20%).
#
# 5. Entrena un modelo de MSV y un modelo de Árboles de desición. ¿Qué hiperparámetros son los más adecuados?
#
# 6. Obten las predicciones de los modelos.
#
# 7. Realiza la evaluación de los modelos.
# ¿Cuál de los dos es mejor haciendo la clasifiación de especies?
