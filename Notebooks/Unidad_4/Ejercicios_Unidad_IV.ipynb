# %% [markdown]
# ---
#
# <p align="center">
#   <span style="color:Navy; font-size:200%; font-weight:bold; vertical-align:middle;">
#     Temas Selectos: Python para Ciencias de la Tierra
#   </span>
#   <img src="attachment:LOGO_ENCIT.png" alt="ENCiT" width="120" style="vertical-align:middle; margin-left:20px;"/>
# </p>
#
# <p align="center" style="line-height:1.2;">
#   <span style="color:RoyalBlue; font-size:150%;">Tema 4: Introducción al Aprendizaje Automático (Machine Learning).  </span><br/>
#   <span style="color:DodgerBlue; font-size:130%;">Notebook: Ejercicios en Clase </span><br/>
#   <span style="font-size:100%;color:forestgreen"> Escuela Nacional de Ciencias de la Tierra  |  Semestre 2026-I</span>
# </p>
#
# ---

# %% [markdown]
# # Ejercicio 1: Usando los datos de `'diabetes_clean.csv'`, realiza el análisis univariado y bivariado de los datos.
#
# 1. Muestra una descripción de los estadísticos más importantes.
# 2. Obtén los boxplots e histogramas de las variables.
# 3. Obtén los gráficos de dispersión (pairplots) y los valores de correlación.
# 4. Escoge una variable predictora y una variable dependiente, y estandarízalas.
# 5. Crea los conjuntos de datos de entrenamiento (75%) y prueba (25%).
# 6. Entrena un modelo de regresión lineal uno de MSV regresivo.
# 7. Obtén las predicciones de los modelos.
# 8. Realiza las evaluaciones de los modelos.
# ¿Cuál de los dos fue el mejor?

# %% [markdown]
# # Ejercicio 2: Crearás un modelo que clasifique especies de pingüinos de acuerdo a sus carácterísticas . Entonces, usando `'penguins.csv'`:
#
# 1. Realiza un AED muy simple (Verifica si hay presencia de valores nulos.)
# 2. Crea un DataFrame con las variables predictoras  `'bill_length_mm','bill_depth_mm','flipper_length_mm', 'body_mass_g'` y estandarízalas.
# 3. Crea un DataFrame que contenga la variable objetivo (`'species'`) .
# 4. Crea los conjuntos de datos de entrenamiento (80%) y de prueba (20%).
# 5. Entrena un modelo de MSV.
# 6. Obten las predicciones del modelo.
# 7. Realiza la evaluación del modelo.
