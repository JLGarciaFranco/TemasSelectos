# %% [markdown]
# # <font color="purple"> **Ejercicio 1: Hacia un mundo sustentable**
#
# En el contexto del cambio climático global, la transición hacia energías renovables se ha vuelto una prioridad para muchos países. Pero… ¿realmente todos están avanzando al mismo ritmo?. Para responder esto, vamos a trabajar con datos de diferentes fuentes de generación de energía renovable a nivel mundial (<https://ourworldindata.org/grapher/modern-renewable-energy-consumption>).
#
# ##### <font color="darkblue">**1. Explora la base de datos `modern-renewable-energy-consumption.csv` y describe sus características:**
#
# * Cuántas filas y columnas tiene
# * Qué representan las columnas
# * Frecuencia de los datos
# * Periodo de los datos
# * Unidades
# * ¿Hay valores faltantes?,¿Cómo están representados?
# * Para la columna de `Other renewable`, ¿qué fuentes de energía renovable consideran?
#
# `Nota: En caso de que no puedan intuir características de los datos con solo ver el DataFrame, revisen la documentación de sus datos. Para ello, copien las siguientes líneas de código en una celda.`
#
# ```python
# import requests
#
# # Cargamos los metadatos desde la página web
# metadata = requests.get("https://ourworldindata.org/grapher/modern-renewable-energy-consumption.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()
#
# ```
#
#
# ##### <font color="darkblue">**2. Identifica los valores únicos de las columnas `Entity`, `Code`, `Year`y responde:**
#
#    * A parte de nombres de países, ¿qué otros nombres podemos observar en la columna `Entity` (menciona tres ejemplos)?, ¿Qué crees que representan esos nombres?
#
#      `Hint:Ayúdate de la documentación`
#
#    * ¿Cuántos años totales tiene la base de datos?
#
#    * ¿Cuál de las tres columnas cuenta con valores faltantes?
#
#
#
# ##### <font color="darkblue">**3. Realiza un slicing para seleccionar los datos que contengan `Nan` en la columna `Code`(solo regiones) y realiza otro slicing con la condición opuesta, es decir, selecciona los datos en donde la columna `Code` no tenga `NaN` (solo países). Imprime ambos recortes**
#
#    * Como podrás observar, en el recorte para obtener solo los países se cuela "Word", ¿Por qué crees que pase esto?
#
#    * Modifica el segundo recorte para quitar "Word" y obtener solo los países. Muestra este nuevo DataFrame
#
#
#
# ##### <font color="darkblue"> **4. Selecciona 8 países de tu gusto y realiza lo siguiente:**
#
# * Calcula el promedio, máximos y mínimos de generación por país. `Hint:groupby()`
#
# * Crea una función lambda para calcular la generación total por año de energía por país y agrégalo en una nueva columna. ¿Qué país ha acumulado la mayor producción de energías renovables a lo largo del periodo de los datos?
#
# * Crea un gráfico de línea que represente la evolución en la producción anual de cada tipo de energía renovable para los 10 países. ¿Cómo ha cambiado esta producción?
#
#
#
# ##### <font color="darkblue"> **5. Localiza las filas que representen las regiones con niveles altos, medio-altos y medios de ingresos económicos per cápita.  Realiza el promedio quinquenal(5 años) para cada región y grafica.**
#
# * ¿Cambia la producción de energías limpias en relación a su economía?¿Cómo son esas diferencias?

# %% [markdown]
# # <font color="purple"> **Ejercicio 2: Atlántico en movimiento**
#
# Los huracanes son uno de los fenómenos más intensos dentro de la dinámica de la atmósfera y juegan un papel fundamental en la redistribución de energía en el sistema climático. En este ejercicio analizaremos datos de ciclones tropicales en el océano Atlántico (<https://www.kaggle.com/datasets/utkarshx27/noaa-atlantic-hurricane-database>) con la finalidad de obtener información sobre el comportamiento de estos fenómenos en dicha zona y en cada etapa de su formación.
#
# ##### <font color="darkblue">1.  **Exploración de datos:**
#
#    * Carga los datos `storms.txt`, ¿Con qué tipo de símbolo están delimitados nuestros datos?
#
#    * Carga los datos de tal manera que se separen en columnas.
#
#    * Describe las características más importantes:
#
#       * Cuántas filas y columnas tiene
#       * Qué representan las columnas
#       * Frecuencia de los datos
#       * Periodo de los datos
#       * Unidades
#       * ¿Hay valores faltantes?, ¿Cómo están representados?
#
#      `Nota: Para conocer los metadatos/documentación de estos datos visita el link de la descripción`
#
# ##### <font color="darkblue">2. **A partir de los valores únicos de la columna `status`, que representan las distintas etapas de un ciclón tropical, calcula la frecuencia de cada etapa lo largo del periodo de estudio**
#
# * Además, realiza un gráfico de barras para representar tus resultados.
#
# * ¿Qué etapa es la más y la menos común?
#
#     `**Importante:** Los datos están registrados cada 6 horas, por lo que un mismo ciclón puede aparecer repetido varias veces en el status. Para evitar sobrecontar, debes considerar únicamente una vez cada etapa por ciclón mientras no haya un cambio de status.`
#
# ##### <font color="darkblue"> 3. **Realiza histogramas de frecuencias para los valores de viento y presión por cada etapa de un ciclón tropical en el Atlántico**
#
# * Los histogramas deben estar dentro de un mismo objeto de figura.
# * Las unidades del viento deben de estar en $km/h$.
# * Describe los resultados que obtuviste.
#
#    `**Importante:** Para este caso considera todos los datos sin importar que el status se repita. Esto permite capturar cómo varían estas propiedades a lo largo del tiempo dentro de cada etapa, proporcionando una representación más completa de su comportamiento.`
#
# ##### <font color="darkblue"> 4. **Determina cuántos ciclones tropicales ocurrieron en cada año. Representa tus resultados en un histograma de frecuencias.**
# * ¿En qué intervalo ocurrió una mayor y una menor cantidad de ciclones tropicales?
#
# ##### <font color="darkblue"> 5. **Determina cuántos ciclones tropicales por año lograron llegar a la etapa de huracán. Además, realiza el mismo conteo, pero por categoría del huracán.**
#
# * Realiza un gráfico de línea para representar ambos resultados.
#
# * ¿Ha cambiado el comportamiento de los huracanes con el paso del tiempo?,¿Cómo ha sido es cambio?
#
#   `Nota: Considera la misma instrucción del punto 2 para realizar este conteo.`
#
# ----------------
#
#
#
# ##### <font color="darkblue"> **Extra (+5 puntos): Cambia la resolución temporal de tus datos a datos mensuales. Determina el número de ciclones por mes y representa tus resultados gráficamente (elige el tipo de gráfico que mejor se adecúe). ¿En qué meses ocurre la mayor actividad ciclónica?**

# %% [markdown]
# # <font color="purple"> **Ejercicio 3: Datos de sismos**
#
# Realice el siguiente análisis para los datos de sismos que se encuentran en la carpeta de data. '***SSNMX_catalogo_ejemplo.csv***'
#
# ##### <font color="darkblue">1.  **Exploración de datos:**
#
# Abra los datos y describa brevemente cómo están distribuidos los datos, sus características principales, columnas, etc.
#
# Realice un histograma de frecuencia de la magnitud de los sismos. Añada la línea correspondiente al valor promedio de Magnitud. Interprete sus resultados.
#
#  ##### <font color="darkblue">2.  **¿Y septiemble en sus centros la Tierra?**
#
# Analice la distribución del ciclo anual de conteos de sismos cuya magnitud es superior a 5.5. En este caso, el ciclo anual es una gráfica donde el eje x son los meses (Ene-Dic) y en el eje y el conteo de sismos totales por mes. ¿En qué mes tiembla más? Y si considera ahora sismos con magnitud mayor a 5, que es cuando se activa la alerta sísmica, ¿cambia su respuesta? Interpreta sus resultados.
#
#  ##### <font color="darkblue">3.  **Gráfico de sismos**
#
# Realice una gráfica de la localización de los sismos utilizando **Cartopy**. El gráfico debe ser de dispersión (`plt.scatter()`) y deberás colorear la magnitud de los sismos para mostrar la magnitud de los sismos al mismo tiempo que la distribución.
# Utiliza la proyección que consideres que mejor representa la región principal de los sismos.
#
# Recuerda que todas las gráficas deben ser de alta calidad, como hemos visto en clase y sin escatimar en detalles visuales.

# %% [markdown]
# # <font color="purple"> **Ejercicio 4: El ozono en la región más transparente** </font>
#
# Realice el siguiente análisis de los datos de ozono, vistos en clase, por estación.
#
# 1.   Calcule el ciclo anual de las concentraciones de ozono para 5 estaciones y grafique cada una como una línea individual en la misma gráfica. Recuerde que un ciclo anual es una gráfica donde se muestre en el eje x los meses (12) y en el eje y el promedio por mes. Comente si se observa el mismo ciclo en todas las estaciones.
# 2.   Realice un histograma de frecuencia de la concentración horaria de ozono, separando los datos en una parte diurna (de 8 am a 6 pm) y nocturna (en el complemento de la versión diurna). Son dos histogramas en total, pueden ir en la misma gráfica o en dos paneles.
# 3.   Considere dos pares de estaciones, cuatro estaciones en total. Escoja sus estaciones basada en su cercanía, según el mapa de estaciones disponibles en [Dirección de Monitoreo CDMX](https://www.aire.cdmx.gob.mx/) de las estaciones de monitoreo: dos estaciones cercanas y dos estaciones alejadas. Seleccione sus dataframes con los pares de estaciones.    Para cada estación, calcule el promedio diario de concentración de ozono (o resamplee sus datos originales a frecuencia diaria).
# 4. Realice un gráfico de cajas y bigotes de los dos pares de estación. De nuevo, puede unir las 4 cajas en 1 plot o en 2 subplots.
# 5. Haga una gráfica de serie de tiempo de los datos de estas 4 estaciones, pero resampleados a datos mensuales. Explique si observa o no, una tendencia en los datos, en el período disponible.
#
# Recuerda que todas las gráficas deben ser de alta calidad, como hemos visto en clase y sin escatimar en detalles visuales.
