# %% [markdown]
# # <font color="orange"> **Parte 2**
# # <font color="red">**1.9 Gráficas básicas: Pastel y barras**
#
# La clase pasada vimos los primeros dos tipos de gráficas básicas. Ahora continuaremos con los **gráficos de pastel** (pie charts) y los **gráficos de barra** (bar plot).

# %%
#Importamos las librerías 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# -------
#
# ## <font color="darkblue"> Gráficos de pastel
#
# Un gráfico de pastel es un elemento circular que muestra cómo se divide un total en proporciones o porcentajes. Normalmente los gráficos de pastel se utilizan en negocios para representar operaciones como ventas, resultados de cuestionarios, etc. Son de gran utilidad porque dan un resumen rápido.
# En Matplotlib se pueden hacer gráficos de pastel utilizando la función `.pie()`.
#
# #### <font color="orange"> Ejemplo 1: Mascotas en una veterinaria

# %%
# Vamos a inventar algunos datos sobre mascotas

especies= ['Michis', 'Lomitos', 'Peces Beta', 'Cuyos', 'Tortugas'] #Etiquetas
cantidad = [30, 25, 10, 3,8 ]  #Cantidad de mascotas

#Gráfica de pastel, usando .pie()
plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies)

plt.show()

# %% [markdown]
# **Noten algo**, cada una de las partes del plot tiene una cuña que indica el valor/proporción de cada uno de los elementos en relación al total. Por default, la primer marca empieza desde el eje x y se mueve en contra de las manecillas del reloj.
#
# #### <font color="orange"> Ejemplo 2: Cambiemos el ángulo en el que empieza el primer elemento `startangle`

# %%
# Por default empieza en 0°
plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45)

plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 3: Resaltando un valor `explode`

# %%
#Definimos los valores que indicarán qué tan lejos del centro estarán las cuñas
exp = [0.2, 0.0, 0.5, 0.0, 0.0] # El orden es el que se va graficando, por ejemplo el primero es el de los gatos y el segundo de los lomitos y así sucesivamente

plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45, explode=exp)

plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 4: Efecto de sombra `shadow`

# %%
exp = [0.2, 0.0, 0.0, 0.0, 0.0]

plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45, explode=exp,shadow=True)

plt.show()

# %% [markdown]
# #### <font color="orange">Ejemplo 5: Cambio de colores `colors`

# %%
#Defino los colores
color=["y","m","c","brown","pink"]
exp = [0.2, 0.0, 0.0, 0.0, 0.0]

plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45, explode=exp,shadow=True,colors=color)

plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 6: Agregando los valores porcentuales `autopct`

# %%
#%1.1f%
#Defino los colores
color=["y","m","c","brown","pink"]
exp = [0.2, 0.0, 0.0, 0.0, 0.0]

plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45, explode=exp,shadow=True,colors=color,autopct="%1.2f%%")

plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 7: Moviendo etiquetas `labeldistance`, `pctdistance`

# %%
#Defino los movientos de etiquetas
color=["y","m","c","brown","pink"]
exp = [0.2, 0.0, 0.0, 0.0, 0.0]

plt.figure(figsize=(5,5))

plt.pie(cantidad,labels=especies,startangle = 45, explode=exp,shadow=True,colors=color,autopct="%1.2f%%",labeldistance=1,pctdistance=0.5)
plt.title("Veterinaria")
plt.show()

# %% [markdown]
# ### <font color="brown">Resumen de parámetros útiles para mejorar nuestros gráficos de pastel
# * `startangle`: Rota el gráfico (por default 0$^\circ$)
# * `explode`: Separa una cuña del centro (destacar categoría).
# * `shadow`: Agrega sombra.
# * `colors`: Nos permite definir los colores manualmente.
# * `autopct`: Muestra el porcentaje automáticamente.
# * `labeldistance`: Controla qué tan lejos aparecen los labels.
# * `pctdistance`: Controla la posición del porcentaje.
# * `wedgeprops`: Controla propiedades de las cuñas.

# %% [markdown]
# -----
# ### <font color="purple"> Ejercicio 1: Composición del fitoplancton
#
# Imaginen que están analizando una muestra de agua marina para encontrar la proporción de los siguientes tipos de fitoplancton: *diatomeas, dinoflagelados, cianobacterias, cocolitofóridos y clorofitas*. Realiza un gráfico de pastel para una rápida visualización de tus resultados.
#
# 1. Genera aleatoriamente la cantidad de cada tipo de fitoplancton encontrado en la muestra (*Hint: `np.random.randint()`, usa el rango que prefieras*).
# 2. Destaca el fitoplancton con mayor presencia en la muestra.
# 3. Guarda tu imagen.
#
# **Nota: Piensen que la gráfica es para un trabajo importante, así que mejórenla lo más que puedan.**

# %%
fito=["Diatomeas","Dinoflagelados","Cianobacterias","cocolitofóridos","clorofitas"]

#Paso 1
np.random.seed(88)
cantidad=np.random.randint(10,40,5)
print(cantidad)

# Graficando
colores = [
    "#d7263d",  # rojo intenso
    "#1b998b",  # verde azulado
    "#2e294e",  # azul oscuro
    "#f46036",  # naranja
    "#e2c044",  # amarillo mostaza
    
]
#El que tiener mayor valor es Diatomeas
exp = [0.3, 0.0, 0.0, 0.0, 0.0]
plt.pie(cantidad,labels=fito,startangle = 45, explode=exp,shadow=True,colors=colores,autopct="%1.2f%%",labeldistance=0.9,pctdistance=0.5)
plt.title("Fitoplancton\n")
plt.savefig("Fito.jpg")
plt.show()
# Out:
# [34 10 25 27 20]

# %% [markdown]
# -----
#
# #### <font color="orange"> Ejemplo 8: Pasando de gráfico de pastel a gráfico de dona

# %%
import matplotlib.pyplot as plt

valores = [40, 35, 25]
labels = ["Marítimo", "Continental", "Montaña"]

plt.pie(
    valores,
    labels=labels,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.8,
    wedgeprops={"width": 0.51, "edgecolor": "black"}) #'width' crea el hueco y controla qué tan grueso es el anillo
                                                    #width = 1 → pastel normal
                                                    #width < 1 → dona



plt.title("Tipos de masas de aire",color="red")

plt.show()

# %% [markdown]
# #### <font color="orange">Ejemplo 9: Cambiando los colores de los labels y los porcentajes

# %%
import matplotlib.pyplot as plt

valores = [40, 35, 25]
labels = ["Marítimo", "Continental", "Montaña"]

plt.pie(
    valores,
    labels=labels,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.8,
    wedgeprops={"width": 0.5, "edgecolor": "black"},
    textprops={"color": "darkblue"})  #textprops nos permite cambiar formato del texto como el color



plt.title("Tipos de masas de aire",color="red")

plt.show()

# %% [markdown]
# **También podemos definir un color diferente para cada label**
# (<https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html>).

# %%
import matplotlib.pyplot as plt

valores = [40, 35, 25]
labels = ["Marítimo", "Continental", "Montaña"]
color_labels=["blue","orange","green"]

_,texts,_=plt.pie(
    valores,
    labels=labels,
    autopct="%1.1f%%",
    startangle=90,
    pctdistance=0.8,
    wedgeprops={"width": 0.5, "edgecolor": "black"}) 
print(texts)

#Cambiando el color de los labels
for i, text in enumerate(texts):
    text.set_color(color_labels[i]) #'set_color' es una función que permite cambiar el color de un objeto gráfico o visual.
    

plt.title("Tipos de masas de aire",color="red")

plt.show()
# Out:
# [Text(-1.0461621541481756, 0.33991873621212615, 'Marítimo'), Text(0.4993897495105265, -0.9801070748055101, 'Continental'), Text(0.7778174453921319, 0.7778174732182725, 'Montaña')]

# %% [markdown]
# ---------
#
# ## <font color="darkblue"> Gráficos de barras
#
# Un gráfico de barras se usa para **comparar cantidades entre categorías**. Es ideal cuando tienes datos discretos, es decir, aquellos que se puedan contar. En Matplotlib ocupamos la función `.bar` para gráficos de barras.

# %% [markdown]
# ### <font color="orange"> Ejemplo 1: Alumnos por orientación

# %%
#Definimos nuestros datos
estudiantes = ["Sólidos", "Atmosféricos", "Espaciales", "Acuáticos", "Ambientales"]
cantidad = np.array([3, 8, 1, 10, 3])

#Graficamos
plt.bar(estudiantes, #Categorías o posiciones
        cantidad, #Altura (valores por categoría)
        color = ['#bc6c25' , '#3a86ff', '#14213d', '#0081a7', '#a7c957'], #Colores para cada barra
        width = 0.7)#Ancho de cada barra

plt.title('Cantidad de alumnos por orientación ')
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.xlabel('Orientación')
plt.ylabel('Alumnos')
plt.show()

# %%
# Podemos cambiar la orientación de las barras, ocupando `plt.barh`

#Graficando
plt.barh(estudiantes, 
         cantidad,
         color = ['#bc6c25' , '#3a86ff', '#14213d', '#0081a7', '#a7c957'], 
         height = 0.8) # altura de las barras (valores en eje y), en pocas palabras el grosor en barras horizontales

plt.title('Cantidad de alumnos por orientación ')
plt.xlabel('Orientación')
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.ylabel('Alumnos')
plt.show()

# %% [markdown]
# #### <font color="orange"> Ejemplo 2: Múltiples barras por categoría

# %%
#Vamos a mostrar características de diferentes especies de pingüinos (Los datos vinieron de aqui https://allisonhorst.github.io/palmerpenguins/)

#Especies de pingüinos
especie = ["Adelie", "Chinstrap", "Gentoo"]

adelite  = [18.35, 38.79 ,189.95]  #Cada lista contiene el ancho de su pico, largo del pico y largo de la la aleta
chinstrap = [18.43, 48.83, 195.82]
gentoo = [14.98, 47.50, 217.19]

#Defino el ancho de cada barra
width = 0.20

#GRAFICANDO

#Defino cuántas barras tendré por categoría
x = np.arange(3) #Asignamos un índice a cada categoría

plt.bar(x-0.2, adelite, width,color ='#d9f0ff')
plt.bar(x, chinstrap, width, color ='#a3d5ff')
plt.bar(x+0.2, gentoo, width, color ='#83c9f4')

#Definimos los nombres de las categorías de cada eje
plt.xticks(x,['Ancho Pico', 'Largo Pico', 'Largo Aleta'] )

plt.xlabel("Característica")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.ylabel("Largo en mm")
plt.legend(especie)
plt.show()

# %% [markdown]
# **Con los mismos datos podemos hacer una representación diferente, lo importante es que sepan qué están haciendo.**

# %%
#Ahora quiero que cada categoría sea la especie y las barras sean sus características
especie = ["Adelie", "Chinstrap", "Gentoo"]


#Carácterísticas
ancho_p = [18.35, 18.43, 14.98] #Adelie, Chinstrap, Gentoo
largo_p = [38.79, 48.83, 47.50] 
largo_aleta = [189.95, 195.82, 217.19]

width = 0.20

#GRAFICANDO
x = np.arange(3) 
plt.bar(x-0.2, ancho_p, width,color ='#d9f0ff',edgecolor="black") #'edcolor' color a los bordes
plt.bar(x, largo_p, width, color ='#a3d5ff',edgecolor="black")
plt.bar(x+0.2, largo_aleta, width, color ='#83c9f4',edgecolor="black")
plt.xticks(x,especie )
plt.xlabel("Característica")
plt.ylabel("Largo en mm")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(['Ancho Pico', 'Largo Pico', 'Largo Aleta'], loc = 'upper left', ncols = 3) #'ncols' nos permite definir la cantidad de columnas 
plt.show()                                                                             #dentro de una leyenda

# %% [markdown]
# #### <font color="orange"> Ejemplo 3: Barras apiladas (stacked bar)

# %%
#Queremos ver los días con olas de calor y olas de frío

categorias = ["México","España"]

heat_waves = [50,55]
cold_waves = [20,10]

plt.bar(categorias, heat_waves,width=0.5,label="Olas de calor",color="brown")
plt.bar(categorias, cold_waves,width=0.5,bottom=heat_waves, label="Olas de frío",color="darkblue")  #'bottom' permite apilar

plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(loc="upper center")
plt.show()

# %% [markdown]
# ---
#
# ### <font color="purple">Ejercicio 2: Inventario de rocas
#
# Imaginen que les piden generar un inventario de rocas de un laboratorio y graficar tus resultados. Para ello considera que hay rocas metamórficas, ígneas y sedimentarias. Dentro de las metarmóficas se encuentran la pizarra y el mármol; en las ígneas, basalto y el granito; en las sedimentarias, caliza y conglomerado.
#
# 1. Define la cantidad de pizarras, mármoles, basaltos, granitos, calizas y conglomerados (elige los valores que quieras).
#
# 2. Con los datos realiza un gráfico de barras en donde se represente la cantidad de rocas por cada categoría, por ejemplo para la categoría metarmófica cuántas pizarras y mármoles se encontraron y así sucesivamente (`Hint: Barras múltiples por categoría`).
#
# 3. Ahora realiza un gráfico en donde apiles la cantidad de rocas encontradas para cada categoría.

# %%
import matplotlib.pyplot as plt
import numpy as np

#Definimos las categorías
categorias=["metamórficas","ígneas","sedimentarias"]

#Definimos la cantidad de rocas en el inventario
pizarra,marmol,basalto,granito,caliza,conglomerado=2,4,5,1,9,29

# Agrupamos los datos, en este caso queremos que aparezca dos barras por categoría, por lo tanto hacemos dos subgrupos
#Python toma cada agrupamiento y grafica por índices, es decir, toma el índice 0 de Tipo1 y posteriormente el índice0 de Tipo2 y eso 
#lo gráfica en la primera categoría.

Tipo1=[pizarra,basalto,caliza] #metamórfica, ígnea, sedimentaria
Tipo2=[marmol,granito,conglomerado]

#GRAFICANDO
#En X siempre debe de ir la cantidad de categorías, no de barras
x = np.arange(3) 

#La cantidad de plt.bar() que usen dependerá de la cantidad de barras que quieran en cada categoría

plt.bar((x-0.1), Tipo1, width=0.20,color ='#d9f0ff',edgecolor="black") #'edcolor' color a los bordes
plt.bar(x+0.1, Tipo2, width=0.20, color ='#a3d5ff',edgecolor="black")

plt.xticks(x,categorias )
plt.xlabel("Tipo roca")
plt.ylabel("Cantidad")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(["pizarra","marmol","basalto","granito","caliza","conglomerado"], loc = 'upper left', ncols = 3) #'ncols' nos permite definir la cantidad de columnas 
plt.show()                                                                             #dentro de una leyenda

# %%
import matplotlib.pyplot as plt
import numpy as np

#Definimos las categorías
categorias=["metamórficas","ígneas","sedimentarias"]

#Definimos la cantidad de rocas en el inventario
pizarra,marmol,basalto,granito,caliza,conglomerado=2,4,5,1,9,29

# Agrupamos los datos, en este caso queremos que aparezca dos barras por categoría, por lo tanto hacemos dos subgrupos
#Python toma cada agrupamiento y grafica por índices, es decir, toma el índice 0 de Tipo1 y posteriormente el índice0 de Tipo2 y eso 
#lo gráfica en la primera categoría.

Tipo1=[pizarra,basalto,caliza] #metamórfica, ígnea, sedimentaria
Tipo2=[marmol,granito,conglomerado]

#GRAFICANDO
#En X siempre debe de ir la cantidad de categorías, no de barras
x = np.arange(3) 

#La cantidad de plt.bar() que usen dependerá de la cantidad de barras que quieran en cada categoría

plt.bar((x-0.1), Tipo1, width=0.20,color =["red","orange","gray"], label=["pizarra","basalto","caliza"],edgecolor="black") #'edcolor' color a los bordes
plt.bar(x+0.1, Tipo2, width=0.20, color =["pink","darkblue","brown"], label=["marmol","granito","conglomerado"],edgecolor="black")

plt.xticks(x,categorias )
plt.xlabel("Tipo roca")
plt.ylabel("Cantidad")
plt.legend(loc="upper left",ncols=2)
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#Definimos las categorías
categorias=["metamórficas","ígneas","sedimentarias"]

#Definimos la cantidad de rocas en el inventario
pizarra,marmol,basalto,granito,caliza,conglomerado=2,4,5,1,9,29

# Agrupamos los datos, en este caso queremos que aparezca dos barras por categoría, por lo tanto hacemos dos subgrupos
#Python toma cada agrupamiento y grafica por índices, es decir, toma el índice 0 de Tipo1 y posteriormente el índice0 de Tipo2 y eso 
#lo gráfica en la primera categoría.

Tipo1=[pizarra,basalto,caliza] #metamórfica, ígnea, sedimentaria
Tipo2=[marmol,granito,conglomerado]

#GRAFICANDO
#En X siempre debe de ir la cantidad de categorías, no de barras
x = np.arange(3) 

#La cantidad de plt.bar() que usen dependerá de la cantidad de barras que quieran en cada categoría
plt.bar(x-0.1, Tipo1, width=0.20,color =["pink","pink","pink"], label=["pizarra","basalto","caliza"],edgecolor="black") #'edcolor' color a los bordes
plt.bar(x+0.1, Tipo2, width=0.20, color=["gray","gray","gray"], label=["marmol","granito","conglomerado"],edgecolor="black")


#Agregando etiquetas por medio de texto
plt.text(-0.25,2.5,"Pizarra",color="brown") #plt.text(x,y,texto)
plt.text(0.01,4.5,"Mármol",color="brown") 

plt.text(0.8,5.2,"Basalto",color="brown") 
plt.text(1,1.5,"Granito",color="brown")

plt.text(1.7,10,"Caliza",color="brown") 
plt.text(1.7,29.5,"Conglomerado",color="brown") 

plt.xticks(x,categorias )
plt.xlabel("Tipo roca")
plt.ylabel("Cantidad")
plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.show()

# %%
#Apilando la cantidad de rocas por categoría

categorias = ["Metamórficas","Ígneas","Sedimentarias"]

#Retomando los valores anteriores
Tipo1=[pizarra,basalto,caliza] #metamórfica, ígnea, sedimentaria
Tipo2=[marmol,granito,conglomerado]

plt.bar(categorias, Tipo1,width=0.5,color =["salmon","orange","purple"], label=["pizarra","basalto","caliza"])
plt.bar(categorias, Tipo2,width=0.5,bottom=Tipo1,  color =["pink","darkblue","brown"], label=["marmol","granito","conglomerado"])


plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(loc="upper left", ncols=2)
plt.yticks(np.arange(0,40,2))
plt.ylabel("Cantidad")
plt.show()

# %%
#Definimos las categorías
categorias=["metamórficas","ígneas","sedimentarias"]

#Definimos la cantidad de rocas en el inventario
pizarra,marmol,gneis,basalto,granito,pomez,caliza,conglomerado,yeso=32,11,2,4,5,1,9,29,7

Tipo1=[pizarra,basalto,caliza] #metamórfica, ígnea, sedimentaria
Tipo2=[marmol,granito,conglomerado]
Tipo3=[gneis, pomez,yeso]

#print(Tipo2+Tipo3)
#print(np.array(Tipo1)+np.array(Tipo2))

plt.bar(categorias, Tipo1,width=0.5,color =["salmon","orange","purple"], label=["pizarra","basalto","caliza"])
plt.bar(categorias, Tipo2,width=0.5,bottom=Tipo1,color =["pink","darkblue","brown"], label=["marmol","granito","conglomerado"])
plt.bar(categorias, Tipo3,width=0.5, bottom=np.array(Tipo1)+np.array(Tipo2), color =["yellow","gold","silver"], label=["gneis","pomez","yeso"])


plt.grid(linestyle="--", color="gray",alpha=0.2)
plt.legend(loc="upper center", ncols=2)
plt.yticks(np.arange(0,50,2))
plt.ylabel("Cantidad")
plt.show()
